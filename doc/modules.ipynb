# %% [markdown]
# <div align="center"><h1 style="font-size: 2em; font-weight: 700">List modules for this course</h1></div>

# %% [markdown]
# ---

# %% [markdown]
# **Модуль 1: Основы языка C++**
#
# - Введение в C++ и его некоторые моменты
# - Установка и настройка среды разработки
# - Структура программы на C++
# - Переменные и операторы
# - Условные выражения и циклы
# - Ввод и вывод данных
# - Функции и процедуры
# - Массивы и указатели
#
# **Модуль 2: Углубленное программирование**
# ***ООП (объектно-ориентированное программирование) в С++***
# - Классы и объекты
# - Конструкторы и деструкторы
# - Наследование и полиморфизм
#
# ***Шаблоны (template)*** <br/>
# ***Ввод и вывод файлов***
#
# **Модуль 3: Расширенные темы**
#
# - Стандартная библиотека C++
# - Управление памятью и динамическое выделение
# - Работа с объектами и классами в стандартной библиотеке
# - Многопоточное программирование
# - Структуры данных
# - Работа с файлами
# - Оптимизация и профилирование кода
#
# ---
#
# **Практические примеры и проекты**
